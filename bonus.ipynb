# %%
from astropy.io import fits
fits_file = fits.open('bonus_image_1.fits')
fits_file.info()
# Out:
# Filename: bonus_image_1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     161   (891, 893)   int16
#   1  er.mask       1 TableHDU        25   1600R x 4C   [F6.2, F6.2, F6.2, F6.2]

# %%
image_data = fits_file[0].data
print(image_data)
# Out:
# [[ 7201  6642  6642 ...  9498  9498 10057]
#  [ 6642  6363  6642 ... 10057 10616 10616]
#  [ 6922  6642  6922 ... 10337 11175 10616]
#  ...
#  [ 5412  5132  5412 ... 13000 12580 12021]
#  [ 5796  5517  5796 ... 12546 12546 11987]
#  [ 5796  5796  6076 ... 11987 12546 12546]]

# %%
#printing image 
import matplotlib.pyplot as plt

plt.figure()
plt.imshow(image_data, origin = 'lower', cmap = 'inferno')
plt.colorbar()
plt.show()

# %%
#printing image 
import matplotlib.pyplot as plt

plt.figure()
plt.imshow(image_data, origin = 'lower', cmap = 'ocean')
plt.colorbar()
plt.show()

# %%
#printing image 
import matplotlib.pyplot as plt

plt.figure()
plt.imshow(image_data, origin = 'lower', cmap = 'gist_earth')
plt.colorbar()
plt.show()

# %%
#printing image 
import matplotlib.pyplot as plt

plt.figure()
plt.imshow(image_data, origin = 'lower', cmap = 'copper')
plt.colorbar()
plt.show()

# %%
m = fits_file[1].data.columns
print(m)
# Out:
# ColDefs(
#     name = 'XI'; format = 'F6.2'; unit = 'DEGREES'; start = 1
#     name = 'ETA'; format = 'F6.2'; unit = 'DEGREES'; start = 7
#     name = 'XI_CORR'; format = 'F6.2'; unit = 'ARCSEC'; start = 13
#     name = 'ETA_CORR'; format = 'F6.2'; unit = 'ARCSEC'; start = 19
# )

# %%
#printing graph
import matplotlib.pyplot as plt
from astropy.io import fits

fits_file = 'bonus_image_1.fits'

with fits.open(fits_file, mode = 'readonly') as hdul: 
   eta = hdul[1].data['ETA']
   eta_corr = hdul[1].data['ETA_CORR']

# Plotting the graph
plt.plot(eta, eta_corr, marker='o', linestyle='-', color='black')
plt.title('ETA vs ETA_CORR')
plt.xlabel('ETA')
plt.ylabel('ETA_CORR')
plt.grid(True)
plt.show()
